# %%
# Impoting required packages
import pandas as pd
import numpy as np

# setting default option
pd.set_option("mode.copy_on_write", True)

# %%
# importing datasets
df = pd.read_parquet("../../Data/processed/mortality.parquet")
df.sample(5)
# Out:
#      State      County County_Code  Year  \
# 8599    DE  NEW CASTLE       10003  2014
# 6549    TX      DENTON       48121  2011
# 3651    KY   JEFFERSON       21111  2008
# 9216    SC   GREENWOOD       45047  2014
# 1779    TX       BEXAR       48029  2005
#
#                                                   Cause  Deaths
# 8599       Drug poisonings (overdose) Suicide (X60-X64)      16
# 6549  Drug poisonings (overdose) Unintentional (X40-...      59
# 3651  Drug poisonings (overdose) Unintentional (X40-...      78
# 9216  Drug poisonings (overdose) Unintentional (X40-...      10
# 1779  Drug poisonings (overdose) Unintentional (X40-...     140

# %%
population = pd.read_parquet("../../Data/processed/population.parquet")
population.sample(5)
# Out:
#               State State_Code      County County_Code  Year  Population
# 6591        Georgia         13  WASHINGTON       13303  2003       21110
# 37160      Virginia         51     PATRICK       51141  2009       18562
# 5646        Georgia         13       IRWIN       13155  2007        9493
# 33288         Texas         48    EASTLAND       48133  2011       18583
# 25527  North Dakota         38      BENSON       38005  2011        6688

# %%
# Dropping Alaska
df = df[df["State"] != "AK"]

# %%
df["Cause"].value_counts()
# Out:
# Cause
# Drug poisonings (overdose) Unintentional (X40-X44)    7538
# Drug poisonings (overdose) Suicide (X60-X64)          1461
# Drug poisonings (overdose) Undetermined (Y10-Y14)      757
# All other drug-induced causes                          625
# Drug poisonings (overdose) Homicide (X85)                2
# Name: count, dtype: int64

# %%
# Dropping poisonong since we have only 2 values
df = df[df["Cause"] != "Drug poisonings (overdose) Homicide (X85)"]

# %%
df.isna().sum()
# Out:
# State          0
# County         0
# County_Code    0
# Year           0
# Cause          0
# Deaths         8
# dtype: int64

# %%
df[df["Deaths"].isna()]
# Out:
#       State              County County_Code  Year  \
# 10345    VA        BEDFORD CITY       51515  2015
# 10346    VA        BEDFORD CITY       51515  2015
# 10348    VA        BEDFORD CITY       51515  2015
# 10349    VA        BEDFORD CITY       51515  2015
# 10351    VA  CLIFTON FORGE CITY       51560  2015
# 10352    VA  CLIFTON FORGE CITY       51560  2015
# 10354    VA  CLIFTON FORGE CITY       51560  2015
# 10355    VA  CLIFTON FORGE CITY       51560  2015
#
#                                                    Cause  Deaths
# 10345  Drug poisonings (overdose) Unintentional (X40-...    <NA>
# 10346       Drug poisonings (overdose) Suicide (X60-X64)    <NA>
# 10348  Drug poisonings (overdose) Undetermined (Y10-Y14)    <NA>
# 10349                      All other drug-induced causes    <NA>
# 10351  Drug poisonings (overdose) Unintentional (X40-...    <NA>
# 10352       Drug poisonings (overdose) Suicide (X60-X64)    <NA>
# 10354  Drug poisonings (overdose) Undetermined (Y10-Y14)    <NA>
# 10355                      All other drug-induced causes    <NA>

# %%
# drop these NAs for now since they are all in VA and in 2015
df = df.dropna()

# %%
df["Deaths"].describe()
# Out:
# count      10373.0
# mean      37.01475
# std      53.134654
# min           10.0
# 25%           13.0
# 50%           19.0
# 75%           36.0
# max          705.0
# Name: Deaths, dtype: Float64

# %%
population["Population"].describe()
# Out:
# count    4.049500e+04
# mean     9.803144e+04
# std      3.135551e+05
# min      0.000000e+00
# 25%      1.126200e+04
# 50%      2.577600e+04
# 75%      6.644000e+04
# max      1.007726e+07
# Name: Population, dtype: float64

# %%
combined = pd.merge(
    df,
    population,
    on=["County_Code", "Year"],
    how="left",
    validate="m:1",
    indicator=True,
)
combined.sample(5)
# Out:
#      State_x     County_x County_Code  Year  \
# 643       CA  SAN JOAQUIN       06077  2004
# 9602      GA     ROCKDALE       13247  2015
# 9356      WI    JEFFERSON       55055  2014
# 1744      SC   GREENVILLE       45045  2005
# 2710      CA         YOLO       06113  2007
#
#                                                   Cause  Deaths  \
# 643   Drug poisonings (overdose) Unintentional (X40-...      51
# 9602  Drug poisonings (overdose) Unintentional (X40-...      10
# 9356  Drug poisonings (overdose) Unintentional (X40-...      13
# 1744       Drug poisonings (overdose) Suicide (X60-X64)      16
# 2710  Drug poisonings (overdose) Unintentional (X40-...      10
#
#              State_y State_Code     County_y  Population _merge
# 643       California         06  SAN JOAQUIN      642898   both
# 9602         Georgia         13     ROCKDALE       88424   both
# 9356       Wisconsin         55    JEFFERSON       84370   both
# 1744  South Carolina         45   GREENVILLE      405608   both
# 2710      California         06         YOLO      194339   both

# %%
# check if any of them don't have a match
combined[combined["_merge"] == "left_only"]
# Out:
# Empty DataFrame
# Columns: [State_x, County_x, County_Code, Year, Cause, Deaths, State_y, State_Code, County_y, Population, _merge]
# Index: []

# %%
# check counties with no population data
combined["Population"].describe()
# Out:
# count    1.037300e+04
# mean     5.888579e+05
# std      9.580291e+05
# min      1.028200e+04
# 25%      1.315990e+05
# 50%      2.834050e+05
# 75%      6.970800e+05
# max      1.007726e+07
# Name: Population, dtype: float64

# %%
combined["Deaths"].describe()
# Out:
# count      10373.0
# mean      37.01475
# std      53.134654
# min           10.0
# 25%           13.0
# 50%           19.0
# 75%           36.0
# max          705.0
# Name: Deaths, dtype: Float64

# %%
combined.sample(5)
# Out:
#      State_x County_x County_Code  Year  \
# 6819      FL   NASSAU       12089  2012
# 7545      AZ  COCHISE       04003  2013
# 624       CA   ORANGE       06059  2004
# 9226      TN   WILSON       47189  2014
# 3188      PA     ERIE       42049  2007
#
#                                                   Cause  Deaths       State_y  \
# 6819  Drug poisonings (overdose) Unintentional (X40-...      16       Florida
# 7545  Drug poisonings (overdose) Unintentional (X40-...      11       Arizona
# 624                       All other drug-induced causes      14    California
# 9226  Drug poisonings (overdose) Unintentional (X40-...      20     Tennessee
# 3188  Drug poisonings (overdose) Unintentional (X40-...      26  Pennsylvania
#
#      State_Code County_y  Population _merge
# 6819         12   NASSAU       74546   both
# 7545         04  COCHISE      129664   both
# 624          06   ORANGE     2941711   both
# 9226         47   WILSON      125253   both
# 3188         42     ERIE      278573   both

# %%
# clean combined as required
df2 = combined[
    [
        "State_y",
        "State_x",
        "County_x",
        "County_Code",
        "Year",
        "Cause",
        "Deaths",
        "Population",
    ]
]

# %%
df2 = df2.rename(
    columns={"State_y": "State", "State_x": "State_Code", "County_x": "County"}
)

# %%
df2.sample(5)
# Out:
#            State State_Code       County County_Code  Year  \
# 3614     Indiana         IN  VANDERBURGH       18163  2008
# 2605   Wisconsin         WI         ROCK       55105  2006
# 1360     Florida         FL     PINELLAS       12103  2005
# 10253      Texas         TX      RANDALL       48381  2015
# 8716     Indiana         IN         LAKE       18089  2014
#
#                                                    Cause  Deaths  Population
# 3614        Drug poisonings (overdose) Suicide (X60-X64)      10      178053
# 2605   Drug poisonings (overdose) Unintentional (X40-...      20      158538
# 1360   Drug poisonings (overdose) Unintentional (X40-...     145      929426
# 10253  Drug poisonings (overdose) Unintentional (X40-...      11      130463
# 8716   Drug poisonings (overdose) Unintentional (X40-...      39      491259

# %%
# Claculating Mortality Rate
df3 = df2.copy()
df3["Mortality_Rate"] = df3["Deaths"] / df3["Population"]

# %%
df3.sample(5)
# Out:
#         State State_Code     County County_Code  Year  \
# 413    Oregon         OR  CLACKAMAS       41005  2003
# 2862     Iowa         IA       POLK       19153  2007
# 4808    Texas         TX      BEXAR       48029  2009
# 1382  Georgia         GA     DEKALB       13089  2005
# 3889     Ohio         OH   CLERMONT       39025  2008
#
#                                                   Cause  Deaths  Population  \
# 413                       All other drug-induced causes      10      352032
# 2862  Drug poisonings (overdose) Unintentional (X40-...      22      413024
# 4808       Drug poisonings (overdose) Suicide (X60-X64)      25     1685628
# 1382  Drug poisonings (overdose) Unintentional (X40-...      22      668998
# 3889  Drug poisonings (overdose) Unintentional (X40-...      39      195891
#
#       Mortality_Rate
# 413         0.000028
# 2862        0.000053
# 4808        0.000015
# 1382        0.000033
# 3889        0.000199

# %%
# Calculating Mortality Rate for each casue at state level
df4 = (
    df3.groupby(["State", "State_Code", "Year", "Cause"])
    .agg({"Deaths": "sum", "Population": "sum"})
    .reset_index()
)

# %%
df4.sample(5)
# Out:
#          State State_Code  Year  \
# 453   Illinois         IL  2013
# 877    Montana         MT  2014
# 1048  New York         NY  2013
# 332    Georgia         GA  2004
# 337    Georgia         GA  2005
#
#                                                   Cause  Deaths  Population
# 453        Drug poisonings (overdose) Suicide (X60-X64)      97     6868534
# 877                       All other drug-induced causes      12       65764
# 1048  Drug poisonings (overdose) Undetermined (Y10-Y14)      55      871124
# 332                       All other drug-induced causes      11      809481
# 337   Drug poisonings (overdose) Unintentional (X40-...     359     4837328

# %%
# check if all states have a rate for each year
df4[["State", "Year"]]["State"].value_counts()  # .sort_values().value_counts()
# Out:
# State
# California              52
# Michigan                52
# Arizona                 52
# Texas                   51
# New York                49
# Pennsylvania            49
# Oregon                  49
# Indiana                 49
# Florida                 47
# Utah                    46
# Maryland                45
# Ohio                    45
# Massachusetts           43
# Washington              42
# Illinois                42
# Minnesota               38
# Wisconsin               36
# Tennessee               36
# Hawaii                  35
# Oklahoma                35
# Kentucky                34
# District of Columbia    34
# Colorado                33
# Alabama                 32
# Georgia                 32
# Connecticut             32
# Missouri                31
# Nevada                  31
# Louisiana               31
# New Jersey              31
# New Mexico              28
# Virginia                25
# Kansas                  25
# North Carolina          25
# Idaho                   25
# South Carolina          24
# Delaware                24
# Arkansas                24
# Rhode Island            22
# Montana                 21
# Iowa                    21
# New Hampshire           20
# Nebraska                17
# Maine                   15
# Mississippi             13
# West Virginia           13
# Vermont                  7
# Wyoming                  7
# South Dakota             5
# North Dakota             1
# Name: count, dtype: int64

# %%
df3[["State", "Cause"]].drop_duplicates()["State"].value_counts().value_counts()
# Out:
# count
# 4    29
# 3    10
# 2     6
# 1     5
# Name: count, dtype: int64

# %%
df4["State_Mortality_Rate"] = df4["Deaths"] / df4["Population"]

# %%
# combinations of state and county
st_county = df3[["State", "State_Code", "County", "County_Code"]].drop_duplicates()

# %%
# create cross join on state level and county
master = pd.merge(
    df4, st_county, on=["State", "State_Code"], how="left", indicator=True
)

# %%
master.sample(5)
# Out:
#                 State State_Code  Year  \
# 27670          Oregon         OR  2014
# 19213      New Jersey         NJ  2005
# 30822  South Carolina         SC  2015
# 2474       California         CA  2007
# 36997      Washington         WA  2005
#
#                                                    Cause  Deaths  Population  \
# 27670                      All other drug-induced causes      31     1137275
# 19213  Drug poisonings (overdose) Unintentional (X40-...     686     8264855
# 30822  Drug poisonings (overdose) Unintentional (X40-...     577     3606472
# 2474   Drug poisonings (overdose) Unintentional (X40-...    2992    35482979
# 36997  Drug poisonings (overdose) Unintentional (X40-...     600     5499086
#
#        State_Mortality_Rate       County County_Code _merge
# 27670              0.000027      CLATSOP       41007   both
# 19213              0.000083    HUNTERDON       34019   both
# 30822               0.00016  SPARTANBURG       45083   both
# 2474               0.000084       MADERA       06039   both
# 36997              0.000109     THURSTON       53067   both

# %%
master_2 = master[
    [
        "State",
        "State_Code",
        "County",
        "County_Code",
        "Year",
        "Cause",
        "State_Mortality_Rate",
    ]
]

# %%
master_2.sample(5)
# Out:
#               State State_Code      County County_Code  Year  \
# 16421      Michigan         MI      INGHAM       26065  2010
# 5540        Florida         FL  PALM BEACH       12099  2007
# 7938        Georgia         GA     MADISON       13195  2014
# 30156  Pennsylvania         PA      CARBON       42025  2015
# 32963         Texas         TX  MONTGOMERY       48339  2005
#
#                                                    Cause  State_Mortality_Rate
# 16421  Drug poisonings (overdose) Undetermined (Y10-Y14)              0.000028
# 5540   Drug poisonings (overdose) Unintentional (X40-...               0.00013
# 7938                       All other drug-induced causes              0.000013
# 30156  Drug poisonings (overdose) Undetermined (Y10-Y14)              0.000041
# 32963                      All other drug-induced causes              0.000012

# %%
# merge with the original data
df5 = pd.merge(
    master_2,
    df3,
    on=["State", "State_Code", "County", "County_Code", "Year", "Cause"],
    how="left",
    indicator=True,
    validate="1:1",
)

# %%
df5.sample(5)
# Out:
#               State State_Code        County County_Code  Year  \
# 33670         Texas         TX         ELLIS       48139  2008
# 3624     California         CA        MADERA       06039  2014
# 4752        Florida         FL     HIGHLANDS       12055  2003
# 27944  Pennsylvania         PA  PHILADELPHIA       42101  2003
# 26436      Oklahoma         OK      DELAWARE       40041  2006
#
#                                                    Cause  \
# 33670                      All other drug-induced causes
# 3624                       All other drug-induced causes
# 4752                       All other drug-induced causes
# 27944  Drug poisonings (overdose) Unintentional (X40-...
# 26436       Drug poisonings (overdose) Suicide (X60-X64)
#
#        State_Mortality_Rate  Deaths  Population  Mortality_Rate     _merge
# 33670              0.000008    <NA>         NaN            <NA>  left_only
# 3624                0.00001    <NA>         NaN            <NA>  left_only
# 4752               0.000008    <NA>         NaN            <NA>  left_only
# 27944              0.000102     238   1493802.0        0.000159       both
# 26436              0.000025    <NA>         NaN            <NA>  left_only

# %%
# Remap with population data to get county population
df6 = pd.merge(
    df5,
    population[["County_Code", "Year", "Population"]],
    on=["County_Code", "Year"],
    how="left",
    validate="m:1",
    indicator="merge2",
)

# %%
df6.sample(5)
# Out:
#             State State_Code           County County_Code  Year  \
# 9417     Illinois         IL           MARION       17121  2014
# 2442   California         CA  SAN LUIS OBISPO       06079  2007
# 26841    Oklahoma         OK         DELAWARE       40041  2012
# 34047       Texas         TX          ARANSAS       48007  2009
# 25849        Ohio         OH         RICHLAND       39139  2014
#
#                                                    Cause  \
# 9417   Drug poisonings (overdose) Unintentional (X40-...
# 2442   Drug poisonings (overdose) Undetermined (Y10-Y14)
# 26841  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 34047  Drug poisonings (overdose) Unintentional (X40-...
# 25849  Drug poisonings (overdose) Unintentional (X40-...
#
#        State_Mortality_Rate  Deaths  Population_x  Mortality_Rate     _merge  \
# 9417               0.000115    <NA>           NaN            <NA>  left_only
# 2442               0.000006    <NA>           NaN            <NA>  left_only
# 26841              0.000026    <NA>           NaN            <NA>  left_only
# 34047              0.000085    <NA>           NaN            <NA>  left_only
# 25849              0.000234      31      122030.0        0.000254       both
#
#        Population_y merge2
# 9417          38573   both
# 2442         262770   both
# 26841         41733   both
# 34047         23291   both
# 25849        122030   both

# %%
df6["merge2"].value_counts()
# Out:
# merge2
# both          38783
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
def new_death(row):
    if pd.isna(row["Deaths"]):
        return min(int(row["Population_y"] * row["State_Mortality_Rate"]), 9)
    else:
        return row["Deaths"]

# %%
df6["Deaths_2"] = df6.apply(new_death, axis=1)

# %%
df6.sample(5)
# Out:
#           State State_Code     County County_Code  Year  \
# 5379    Florida         FL     PUTNAM       12107  2006
# 5106    Florida         FL     MONROE       12087  2005
# 12152  Kentucky         KY  MCCRACKEN       21145  2007
# 17919  Missouri         MO  JEFFERSON       29099  2007
# 33247     Texas         TX    TARRANT       48439  2006
#
#                                                    Cause  \
# 5379   Drug poisonings (overdose) Unintentional (X40-...
# 5106        Drug poisonings (overdose) Suicide (X60-X64)
# 12152  Drug poisonings (overdose) Unintentional (X40-...
# 17919  Drug poisonings (overdose) Unintentional (X40-...
# 33247       Drug poisonings (overdose) Suicide (X60-X64)
#
#        State_Mortality_Rate  Deaths  Population_x  Mortality_Rate     _merge  \
# 5379               0.000122    <NA>           NaN            <NA>  left_only
# 5106               0.000021    <NA>           NaN            <NA>  left_only
# 12152              0.000156    <NA>           NaN            <NA>  left_only
# 17919              0.000106      19      214948.0        0.000088       both
# 33247              0.000013      12     1662005.0        0.000007       both
#
#        Population_y merge2  Deaths_2
# 5379          74663   both         9
# 5106          75819   both         1
# 12152         64925   both         9
# 17919        214948   both        19
# 33247       1662005   both        12

# %%
df7 = df6[
    [
        "State",
        "State_Code",
        "County",
        "County_Code",
        "Year",
        "Cause",
        "Deaths_2",
        "Population_y",
    ]
]

df7 = df7.rename(columns={"Population_y": "Population", "Deaths_2": "Deaths"})

# %%
df8 = (
    df7.groupby(["State", "State_Code", "County", "County_Code", "Year"])
    .agg({"Deaths": "sum", "Population": "mean"})
    .reset_index()
)

# %%
df8.sample(5)
# Out:
#                State State_Code    County County_Code  Year  Deaths  \
# 13090  West Virginia         WV     WAYNE       54099  2012      10
# 10755      Tennessee         TN    HARDIN       47071  2006       5
# 9263        Oklahoma         OK    ROGERS       40131  2006      13
# 6170        Missouri         MO    WARREN       29219  2011       4
# 3034        Illinois         IL  TAZEWELL       17179  2008      18
#
#        Population
# 13090     41933.0
# 10755     25863.0
# 9263      82234.0
# 6170      32615.0
# 3034     133893.0

# %%
df8["Mortality_Rate"] = df8["Deaths"] / df8["Population"]

# %%
# write to parquet
df8.to_parquet("../../Data/processed/mortality_corrected.parquet", index=False)
